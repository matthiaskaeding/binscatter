# %%
try:
    get_ipython().run_line_magic("load_ext", "autoreload")
    get_ipython().run_line_magic("autoreload", "2")
except NameError:
    pass

import polars as pl
import numpy as np
from plotnine import ggplot, aes, geom_point
from plotnine import labs

from binscatter import binscatter

# %%
def make_data(n):
    x = np.random.normal(0, 1, n)
    y = 0.5 * x**2 + 0.3 * x + np.sin(x / 0.3) + np.random.normal(0, 0.5, n)
    return pl.DataFrame({"x_col": x, "y_col": y})


df = make_data(10000)

# %%
# Data
ggplot(df, aes("x_col", "y_col")) + geom_point(alpha=0.5)

# %%
binscatter_plot = binscatter(df.select("y_col", "x_col"), 100)
binscatter_plot.show()
# Out:
# .when([(col("x_col")) < (dyn float: -2.3334112218935377)]).then(dyn int: 0).otherwise(.when([(col("x_col")) < (dyn float: -2.064245434729207)]).then(dyn int: 1).otherwise(.when([(col("x_col")) < (dyn float: -1.8986214176826202)]).then(dyn int: 2).otherwise(.when([(col("x_col")) < (dyn float: -1.7643583027840835)]).then(dyn int: 3).otherwise(.when([(col("x_col")) < (dyn float: -1.6530200330342533)]).then(dyn int: 4).otherwise(.when([(col("x_col")) < (dyn float: -1.555316009706293)]).then(dyn int: 5).otherwise(.when([(col("x_col")) < (dyn float: -1.477108935586847)]).then(dyn int: 6).otherwise(.when([(col("x_col")) < (dyn float: -1.4066170567138296)]).then(dyn int: 7).otherwise(.when([(col("x_col")) < (dyn float: -1.3391168440497547)]).then(dyn int: 8).otherwise(.when([(col("x_col")) < (dyn float: -1.2774522985468095)]).then(dyn int: 9).otherwise(.when([(col("x_col")) < (dyn float: -1.2247739924278531)]).then(dyn int: 10).otherwise(.when([(col("x_col")) < (dyn float: -1.1669531242168059)]).then(dyn int: 11).otherwise(.when([(col("x_col")) < (dyn float: -1.1189829688372237)]).then(dyn int: 12).otherwise(.when([(col("x_col")) < (dyn float: -1.0672579576473804)]).then(dyn int: 13).otherwise(.when([(col("x_col")) < (dyn float: -1.0242950120350096)]).then(dyn int: 14).otherwise(.when([(col("x_col")) < (dyn float: -0.9824675680709806)]).then(dyn int: 15).otherwise(.when([(col("x_col")) < (dyn float: -0.9346494030410529)]).then(dyn int: 16).otherwise(.when([(col("x_col")) < (dyn float: -0.8975063960881818)]).then(dyn int: 17).otherwise(.when([(col("x_col")) < (dyn float: -0.864510461753122)]).then(dyn int: 18).otherwise(.when([(col("x_col")) < (dyn float: -0.8256892371578874)]).then(dyn int: 19).otherwise(.when([(col("x_col")) < (dyn float: -0.7885156503550185)]).then(dyn int: 20).otherwise(.when([(col("x_col")) < (dyn float: -0.7565389545794551)]).then(dyn int: 21).otherwise(.when([(col("x_col")) < (dyn float: -0.7190923506303433)]).then(dyn int: 22).otherwise(.when([(col("x_col")) < (dyn float: -0.6916385952311229)]).then(dyn int: 23).otherwise(.when([(col("x_col")) < (dyn float: -0.6575690385892295)]).then(dyn int: 24).otherwise(.when([(col("x_col")) < (dyn float: -0.6254110741171017)]).then(dyn int: 25).otherwise(.when([(col("x_col")) < (dyn float: -0.5955563144774848)]).then(dyn int: 26).otherwise(.when([(col("x_col")) < (dyn float: -0.5657386148201368)]).then(dyn int: 27).otherwise(.when([(col("x_col")) < (dyn float: -0.5411640794307321)]).then(dyn int: 28).otherwise(.when([(col("x_col")) < (dyn float: -0.5120186364293271)]).then(dyn int: 29).otherwise(.when([(col("x_col")) < (dyn float: -0.48571874718968183)]).then(dyn int: 30).otherwise(.when([(col("x_col")) < (dyn float: -0.45739438119973447)]).then(dyn int: 31).otherwise(.when([(col("x_col")) < (dyn float: -0.4286243818623729)]).then(dyn int: 32).otherwise(.when([(col("x_col")) < (dyn float: -0.3994969430742066)]).then(dyn int: 33).otherwise(.when([(col("x_col")) < (dyn float: -0.3744587258836662)]).then(dyn int: 34).otherwise(.when([(col("x_col")) < (dyn float: -0.34886758719110633)]).then(dyn int: 35).otherwise(.when([(col("x_col")) < (dyn float: -0.3192974283058843)]).then(dyn int: 36).otherwise(.when([(col("x_col")) < (dyn float: -0.29724140099944607)]).then(dyn int: 37).otherwise(.when([(col("x_col")) < (dyn float: -0.27172096869575624)]).then(dyn int: 38).otherwise(.when([(col("x_col")) < (dyn float: -0.24373899919610126)]).then(dyn int: 39).otherwise(.when([(col("x_col")) < (dyn float: -0.2164595099013439)]).then(dyn int: 40).otherwise(.when([(col("x_col")) < (dyn float: -0.1911567007079728)]).then(dyn int: 41).otherwise(.when([(col("x_col")) < (dyn float: -0.16478339700586014)]).then(dyn int: 42).otherwise(.when([(col("x_col")) < (dyn float: -0.14000970070978136)]).then(dyn int: 43).otherwise(.when([(col("x_col")) < (dyn float: -0.11626120591140601)]).then(dyn int: 44).otherwise(.when([(col("x_col")) < (dyn float: -0.08957989024612097)]).then(dyn int: 45).otherwise(.w ...

# %%
# This is a simple ggplot object so we add layers afters
binscatter_plot + labs(title="Binscatter plots: x vs y")

# %%
dir(binscatter_plot)
binscatter_plot.labels.x
# Out:
# 'x_col'
