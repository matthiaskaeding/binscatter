# %% [markdown]
# # Binscatter Demo
#
# Binscatter plots group the x-axis into bins and plot average outcomes for each bin. This is useful when you have large datasets with overplotting, want to visualize conditional means, or need to control for confounders.

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio

from binscatter import binscatter

pio.renderers.default = "png"
pio.renderers["png"].scale = 4  # High resolution for GitHub

gapminder = px.data.gapminder()

np.random.seed(1)

# Simulated data with polynomial relationship
x = np.random.uniform(0, 10, 500)
poly_data = pd.DataFrame(
    {"x": x, "y": 2 + 0.5 * x + 0.3 * x**2 + np.random.normal(0, 2, 500)}
)

# Simulated confounded data
n = 300
group = np.repeat(["A", "B", "C"], n // 3)
group_effect = np.where(group == "A", 0, np.where(group == "B", 5, 10))
conf_x = np.random.normal(0, 1, n) + group_effect
conf_y = -0.5 * conf_x + 2 * group_effect + np.random.normal(0, 1, n)
confounded_data = pd.DataFrame({"x": conf_x, "y": conf_y, "group": group})

# %% [markdown]
# ## 1. Basic Binscatter Plot
#
# Let's start with a simple example: GDP per capita vs. Life Expectancy from the Gapminder dataset.

# %%
# Basic binscatter plot
fig = binscatter(gapminder, x="gdpPercap", y="lifeExp")
# fig is a Plotly figure, so we can use any available Plotly methods on it
fig.update_layout(title="GDP per Capita vs Life Expectancy (Default DPI selector)")
fig.show()

# %% [markdown]
# ## 2. Automatic Bin Selection Methods
#
# Binscatter supports two automatic bin selection methods:
# - **DPI (Direct Plug-In)**: Default method, provides optimal bin count (shown above)
# - **ROT (Rule-of-Thumb)**: Alternative automatic selector

# %%
# Rule-of-thumb selector
fig_rot = binscatter(gapminder, x="gdpPercap", y="lifeExp", num_bins="rot")
fig_rot.update_layout(title="Rule-of-Thumb Bin Selector")
fig_rot.show()

# %% [markdown]
# ## 3. Manual Bin Specification
#
# You can manually specify the number of bins for more granular or coarser views.

# %%
# Manual bin specification (120 bins)
fig_120 = binscatter(gapminder, x="gdpPercap", y="lifeExp", num_bins=120)
fig_120.update_layout(title="120 Bins")
fig_120.show()

# %% [markdown]
# ## 4. Polynomial Overlay
#
# Add polynomial fit lines to visualize the underlying trend.

# %%
# Quadratic fit overlay
binscatter(poly_data, x="x", y="y", poly_line=2, title="Quadratic Fit").show()

# %% [markdown]
# ## 5. Adjusting for Confounders
#
# Binscatter can partial out control variables, showing the relationship between x and y after adjusting for confounders. Following the original paper, controls are evaluated at their mean level. Categorical controls are handled automatically: those with few levels are one-hot encoded, while high-cardinality ones are absorbed (see the next section).
#
# Here we use `poly_line=1` to highlight the slope change.

# %%
# Without controls - positive relationship (confounded)
binscatter(
    confounded_data, x="x", y="y", poly_line=1, title="Confounded: Positive Slope"
).show()

# Adjusting for group - reveals negative relationship
binscatter(
    confounded_data,
    x="x",
    y="y",
    controls="group",
    poly_line=1,
    title="Adjusted: Negative Slope",
).show()

# %% [markdown]
# ## 6. Integer-Coded Identifiers (`categorical`)
#
# Controls are classified by their dtype. That works for genuine measurements, but identifiers are often stored as integers — `firm_id`, `zip`, `person_id` — and an integer column looks numeric, so it enters the regression as a *single linear term*. Fitting one slope to an arbitrary ID number is almost never what you want, and nothing warns you.
#
# Pass such columns in `categorical` to give them fixed-effect semantics instead:
#
# ```python
# binscatter(df, x="x", y="y", controls=["age", "firm_id"], categorical=["firm_id"])
# ```
#
# `categorical` is an override, not a declaration — string columns are still detected automatically, so you only list the ones whose dtype misleads. It must be a subset of `controls`.
#
# Cardinality is not a problem. A categorical with many levels is **absorbed** rather than one-hot encoded, using group-level sufficient statistics instead of thousands of dummy columns, so 300 firms cost about the same as 3.

# %%
# Firm effects confound the x-y relationship, and firm IDs are integers
rng = np.random.default_rng(0)
n_firms, per_firm = 300, 10

firm_effect = rng.normal(0, 3, n_firms)
firm_id = np.repeat(np.arange(n_firms), per_firm)  # arbitrary labels, as IDs are
eff = firm_effect[firm_id]

fe_x = rng.normal(0, 1, n_firms * per_firm) + eff
fe_data = pd.DataFrame(
    {
        "x": fe_x,
        "y": -0.5 * fe_x + 2 * eff + rng.normal(0, 1, n_firms * per_firm),
        "firm_id": firm_id,
    }
)

# Treated as numeric: one slope on the ID number, which explains nothing
binscatter(
    fe_data,
    x="x",
    y="y",
    controls=["firm_id"],
    poly_line=1,
    title="firm_id as a numeric control: still confounded",
).show()

# Treated as categorical: 300 firm fixed effects, absorbed
binscatter(
    fe_data,
    x="x",
    y="y",
    controls=["firm_id"],
    categorical=["firm_id"],
    poly_line=1,
    title="firm_id as fixed effects: true negative slope",
).show()

# %% [markdown]
# ## 7. Confidence Intervals (`ci`)
#
# `ci` draws an interval around each dot. The two styles answer different questions:
#
# - `ci="pointwise"` — the heteroskedasticity-robust interval for the binscatter estimate itself, i.e. how precisely each bin's mean is pinned down. Centred on the dot.
# - `ci="rbc"` — the robust bias-corrected interval for the *underlying regression function*. The dots are flat within a bin, so they are biased for the true conditional mean; the interval is built from the next-order fit and is deliberately not centred on the dot. This matches `binsreg`'s `ci=(1, 1)`.
#
# Set the level with `ci_level` (default `0.95`). Intervals are only trustworthy when the number of bins is well above the IMSE-optimal choice, so pass `num_bins` explicitly — binscatter warns if you leave it to the automatic selectors.

# %%
# Pointwise: the interval for the dots themselves
binscatter(
    gapminder,
    x="gdpPercap",
    y="lifeExp",
    num_bins=40,
    ci="pointwise",
    title="Pointwise 95% intervals",
).show()

# Robust bias-corrected: the interval for the true conditional mean
binscatter(
    gapminder,
    x="gdpPercap",
    y="lifeExp",
    num_bins=40,
    ci="rbc",
    title="Robust bias-corrected 95% intervals",
).show()

# The bounds are columns on the native output
binscatter(
    gapminder,
    x="gdpPercap",
    y="lifeExp",
    num_bins=40,
    ci="rbc",
    return_type="native",
).head()
# Out:
#     bin   gdpPercap    lifeExp   ci_lower   ci_upper  ci_std_error
# 39    0  375.376331  43.472000  41.185519  45.059691      0.988327
# 37    1  502.532485  41.546846  40.799283  43.748888      0.752464
# 38    2  588.706939  44.878550  42.584472  45.600127      0.769314
# 4     3  662.328679  46.158904  45.121257  48.441090      0.846912
# 2     4  724.016104  45.609366  44.003599  47.767803      0.960274

# %% [markdown]
# ## 8. Return Types
#
# By default, binscatter returns a Plotly figure. Use `return_type="native"` to get the binned data as a dataframe—you get out what you put in.

# %%
# Return as native dataframe
df_binned = binscatter(gapminder, x="gdpPercap", y="lifeExp", return_type="native")
df_binned.head()
# Out:
#     bin   gdpPercap    lifeExp
# 25    0  412.373526  42.819915
# 22    1  571.597773  43.849617
# 3     2  683.415600  46.301498
# 0     3  781.566014  45.168129
# 1     4  889.820568  46.947848

# %% [markdown]
# ## 9. Custom Plotly Arguments
#
# You can pass additional keyword arguments to customize the Plotly scatter plot.

# %%
# Custom title and color
fig_custom = binscatter(
    gapminder,
    x="gdpPercap",
    y="lifeExp",
    title="Economic Development and Longevity",
    color_discrete_sequence=["darkgreen"],
)
fig_custom.show()

# %% [markdown]
# ## 10. Backend Compatibility
#
# Binscatter works with multiple dataframe backends thanks to the narwhals abstraction layer.

# %%
import duckdb
import polars as pl

# Polars
gapminder_pl = pl.from_pandas(gapminder)
binscatter(gapminder_pl, x="gdpPercap", y="lifeExp", title="Polars backend").show()

# DuckDB
gapminder_duck = duckdb.from_df(gapminder)
binscatter(gapminder_duck, x="gdpPercap", y="lifeExp", title="DuckDB backend").show()
